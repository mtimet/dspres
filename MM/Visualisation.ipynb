# %%
from __future__ import print_function

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib notebook

# %%
# Load data into dataframes
# %time train = pd.read_csv(r'data/train.csv')
# %time test = pd.read_csv(r'data/test.csv')
#Enrich
def enrich(df):
    df['Dates'] = pd.to_datetime(df.Dates)
    df['Year'] = df.Dates.dt.year
    df['Month'] = df.Dates.dt.month
    df['DayOfWeek'] = df.Dates.dt.dayofweek
    df['Day'] = df.Dates.dt.date #actual date without the hours

# %time enrich(train)
# %time enrich(test)
# Out:
# CPU times: user 2.87 s, sys: 236 ms, total: 3.11 s
# Wall time: 3.86 s
# CPU times: user 2.3 s, sys: 209 ms, total: 2.51 s
# Wall time: 3.36 s
# CPU times: user 5.39 s, sys: 236 ms, total: 5.63 s
# Wall time: 5.68 s
# CPU times: user 5.25 s, sys: 188 ms, total: 5.44 s
# Wall time: 5.45 s

# %% [markdown]
# ## Spacial Exploration

# %%
train.Y.plot.hist(bins=25)
# Out:
# <img src="data:image/png;base64,...">

# %%
#most of the Y's are below 40
#how many outliers are there?:
len(train[train.Y>40])
# Out:
# 67

# %%
# let's get rid of the outliers and look at the histogram again
train = train[train.Y<40]
train.Y.plot.hist(bins=25)

# %%
#now let's look at the X axis
train.X.plot.hist(bins=25)

# %%
plt.figure()
plt.hist2d(train.X,train.Y,bins=50,cmin=10)
plt.colorbar()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.figure()
plt.hexbin(train.X,train.Y,gridsize=50,bins=50, cmap=plt.cm.coolwarm)
plt.axis([train.X.min(), train.X.max(), train.Y.min(), train.Y.max()])
cb = plt.colorbar()
cb.set_label('counts')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Temporal Exploration

# %%
### Hours

# %%
f = plt.figure()
hours = train.Dates.dt.hour.value_counts()
hours.sort_index(ascending=False,inplace=True)
hours.plot.barh()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### Monthly

# %%
f = plt.figure()
hours = train.Month.value_counts()
hours.sort_index(ascending=False,inplace=True)
hours.plot.barh()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### Yearly

# %%
f = plt.figure()
hours = train.Year.value_counts()
hours.sort_index(ascending=False,inplace=True)
hours.plot.barh()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
f = plt.figure()
hours = train.DayOfWeek.value_counts()
hours.sort_index(ascending=False,inplace=True)
hours.plot.barh()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
from datetime import datetime 
# %time train['DayWithHours'] = train.Dates.map(lambda dt : datetime(dt.year,dt.month,dt.day,dt.hour))

# %%
dayWithHours = train.DayWithHours.value_counts(sort=False)
dayWithHours.sort_index(inplace=True)
dayWithHours
# Out:
# 2003-01-06 00:00:00    14
# 2003-01-06 01:00:00     6
# 2003-01-06 02:00:00    12
# 2003-01-06 03:00:00     3
# 2003-01-06 04:00:00     1
# 2003-01-06 05:00:00    10
# 2003-01-06 06:00:00     5
# 2003-01-06 07:00:00    10
# 2003-01-06 08:00:00    24
# 2003-01-06 09:00:00    16
# 2003-01-06 10:00:00    25
# 2003-01-06 11:00:00    29
# 2003-01-06 12:00:00    13
# 2003-01-06 13:00:00    16
# 2003-01-06 14:00:00    21
# 2003-01-06 15:00:00    15
# 2003-01-06 16:00:00    17
# 2003-01-06 17:00:00    29
# 2003-01-06 18:00:00    37
# 2003-01-06 19:00:00    22
# 2003-01-06 20:00:00    20
# 2003-01-06 21:00:00    14
# 2003-01-06 22:00:00    21
# 2003-01-06 23:00:00    20
# 2003-01-07 00:00:00    17
# 2003-01-07 01:00:00     8
# 2003-01-07 02:00:00     9
# 2003-01-07 03:00:00     6
# 2003-01-07 04:00:00     3
# 2003-01-07 05:00:00     2
#                        ..
# 2015-05-12 18:00:00    18
# 2015-05-12 19:00:00    23
# 2015-05-12 20:00:00    16
# 2015-05-12 21:00:00    19
# 2015-05-12 22:00:00    22
# 2015-05-12 23:00:00     6
# 2015-05-13 00:00:00    11
# 2015-05-13 01:00:00     5
# 2015-05-13 02:00:00    11
# 2015-05-13 03:00:00     1
# 2015-05-13 04:00:00     7
# 2015-05-13 05:00:00    13
# 2015-05-13 06:00:00     5
# 2015-05-13 07:00:00    11
# 2015-05-13 08:00:00    12
# 2015-05-13 09:00:00    18
# 2015-05-13 10:00:00    10
# 2015-05-13 11:00:00     7
# 2015-05-13 12:00:00    21
# 2015-05-13 13:00:00    19
# 2015-05-13 14:00:00    30
# 2015-05-13 15:00:00    23
# 2015-05-13 16:00:00    23
# 2015-05-13 17:00:00    33
# 2015-05-13 18:00:00    27
# 2015-05-13 19:00:00    27
# 2015-05-13 20:00:00    19
# 2015-05-13 21:00:00    12
# 2015-05-13 22:00:00     7
# 2015-05-13 23:00:00    10
# Name: DayWithHours, dtype: int64

# %%
plt.figure()
dayWithHours.plot.line()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.figure()
days = dayWithHours.resample('D').sum()
days.plot.line()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.figure()
days = dayWithHours.resample('W').sum()
days.plot.line()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.figure()
days = dayWithHours.resample('M').sum()
days.plot.area()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Crime Categories

# %%
categories = train.Category.value_counts()
categories
# Out:
# LARCENY/THEFT                  174885
# OTHER OFFENSES                 126165
# NON-CRIMINAL                    92300
# ASSAULT                         76872
# DRUG/NARCOTIC                   53971
# VEHICLE THEFT                   53772
# VANDALISM                       44724
# WARRANTS                        42206
# BURGLARY                        36754
# SUSPICIOUS OCC                  31412
# MISSING PERSON                  25989
# ROBBERY                         22999
# FRAUD                           16679
# FORGERY/COUNTERFEITING          10609
# SECONDARY CODES                  9985
# WEAPON LAWS                      8555
# PROSTITUTION                     7484
# TRESPASS                         7325
# STOLEN PROPERTY                  4539
# SEX OFFENSES FORCIBLE            4387
# DISORDERLY CONDUCT               4318
# DRUNKENNESS                      4280
# RECOVERED VEHICLE                3138
# KIDNAPPING                       2341
# DRIVING UNDER THE INFLUENCE      2268
# RUNAWAY                          1946
# LIQUOR LAWS                      1903
# ARSON                            1513
# LOITERING                        1225
# EMBEZZLEMENT                     1166
# SUICIDE                           508
# FAMILY OFFENSES                   491
# BAD CHECKS                        406
# BRIBERY                           289
# EXTORTION                         256
# SEX OFFENSES NON FORCIBLE         148
# GAMBLING                          146
# PORNOGRAPHY/OBSCENE MAT            22
# TREA                                6
# Name: Category, dtype: int64

# %%
catpct = categories/categories.sum()

print(catpct[:12].sum()) 
cats = catpct[:12].index.tolist()
cats
# Out:
# 0.8907346619862365
# ['LARCENY/THEFT',
#  'OTHER OFFENSES',
#  'NON-CRIMINAL',
#  'ASSAULT',
#  'DRUG/NARCOTIC',
#  'VEHICLE THEFT',
#  'VANDALISM',
#  'WARRANTS',
#  'BURGLARY',
#  'SUSPICIOUS OCC',
#  'MISSING PERSON',
#  'ROBBERY']

# %%
# %time train['SimpleCategory'] = train.Category.map(lambda c: c if c in cats else 'MISC')
train.SimpleCategory.value_counts()
# Out:
# CPU times: user 453 ms, sys: 9.65 ms, total: 463 ms
# Wall time: 464 ms
# LARCENY/THEFT     174885
# OTHER OFFENSES    126165
# MISC               95933
# NON-CRIMINAL       92300
# ASSAULT            76872
# DRUG/NARCOTIC      53971
# VEHICLE THEFT      53772
# VANDALISM          44724
# WARRANTS           42206
# BURGLARY           36754
# SUSPICIOUS OCC     31412
# MISSING PERSON     25989
# ROBBERY            22999
# Name: SimpleCategory, dtype: int64

# %%
plt.figure()
train.SimpleCategory.value_counts(ascending=True).plot.barh()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
# %time train['Monthly'] = train.Dates.map(lambda dt: datetime(dt.year, dt.month, 1))
# Out:
# CPU times: user 6.56 s, sys: 220 ms, total: 6.78 s
# Wall time: 6.79 s

# %%
categoryByMonth = train.groupby(['Monthly','SimpleCategory']).count().unstack()['X']
categoryByMonth
# Out:
# SimpleCategory  ASSAULT  BURGLARY  DRUG/NARCOTIC  LARCENY/THEFT  MISC  \
# Monthly
# 2003-01-01          507       223            455            962   633
# 2003-02-01          490       231            505           1037   617
# 2003-03-01          579       270            287           1125   643
# 2003-04-01          545       303            476           1226   800
# 2003-05-01          636       305            467           1191   804
# 2003-06-01          536       206            380           1142   655
# 2003-07-01          484       211            321            988   622
# 2003-08-01          478       238            380           1029   610
# 2003-09-01          620       219            447           1135   816
# 2003-10-01          667       325            457           1205   919
# 2003-11-01          584       262            396           1092   682
# 2003-12-01          429       224            304            854   522
# 2004-01-01          480       243            441            942   591
# 2004-02-01          498       226            425            916   619
# 2004-03-01          677       327            513           1064   819
# 2004-04-01          614       309            429           1072   792
# 2004-05-01          635       307            462           1123   765
# 2004-06-01          496       220            217           1095   591
# 2004-07-01          486       222            336           1041   568
# 2004-08-01          557       275            475           1127   597
# 2004-09-01          542       272            518           1068   654
# 2004-10-01          643       327            445           1023   671
# 2004-11-01          445       303            304            815   446
# 2004-12-01          393       299            308            822   527
# 2005-01-01          413       316            437            904   627
# 2005-02-01          420       263            358            857   539
# 2014-10-01                 284        336            398       283
# 2014-11-01                 209        330            291       266
# 2014-12-01                 150        288            273       220
# 2015-01-01                 225        278            275       253
# 2015-02-01                 228        241            280       293
# 2015-03-01                 207        367            296       299
# 2015-04-01                 221        313            398       256
# 2015-05-01                  75        108            159        88
#
# [149 rows x 13 columns]

# %%
ax = categoryByMonth.plot.area(subplots=True,layout=(7,2),figsize=(12, 24),sharex=False)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # SEABORN

# %%
import seaborn as sns

# %%
plt.figure()
sns.countplot(y="SimpleCategory", data=train);
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.figure()
sns.countplot(y="SimpleCategory",hue='Year', palette="Greens_d", data=train);
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.figure()
sns.countplot(hue="SimpleCategory",y='PdDistrict', data=train);
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
# misc = train[train.SimpleCategory=='MISC']
clipsize = [[-122.5247, -122.3366],[ 37.699, 37.8299]]
g= sns.FacetGrid(train, col="SimpleCategory", col_wrap=2,size=5)
# %time sns.kdeplot(misc.X,misc.Y,shade=True, shade_lowest=False,gridsize=30, clip=clipsize)
# %time ax = g.map(sns.kdeplot, "X", "Y", shade=True, shade_lowest=False,gridsize=25, clip=clipsize)
# Out:
# <img src="data:image/png;base64,...">
# CPU times: user 1min 3s, sys: 6.62 s, total: 1min 9s
# Wall time: 1min 11s

# %%
# theft = train[train.SimpleCategory=='LARCENY/THEFT']
clipsize = [[-122.5247, -122.3366],[ 37.699, 37.8299]]
g= sns.FacetGrid(train[train.Year>2010], col="Year", col_wrap=4)
# %time sns.kdeplot(misc.X,misc.Y,shade=True, shade_lowest=False,gridsize=30, clip=clipsize)
# %time ax = g.map(sns.kdeplot, "X", "Y", shade=True, shade_lowest=False,gridsize=25, clip=clipsize)
# Out:
# <img src="data:image/png;base64,...">
# CPU times: user 21.8 s, sys: 1.62 s, total: 23.4 s
# Wall time: 23.6 s

# %%
g = sns.jointplot("X", "Y", data=train, bins=20, kind="hex")
# Out:
# <img src="data:image/png;base64,...">

# %%
g= sns.FacetGrid(train, col="SimpleCategory",col_wrap=2)
# %time sns.kdeplot(misc.X,misc.Y,shade=True, shade_lowest=False,gridsize=30, clip=clipsize)
# %time ax = g.map(sns.jointplot, "X", "Y", bins=20, kind="hex")
# Out:
# <div id='29e7d582-5e96-4644-8819-9574b908a997'></div>
# /Users/mtimet/anaconda/lib/python3.5/site-packages/matplotlib/pyplot.py:516: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <div id='c7fa5337-2f74-46f5-b1d5-797e201ea29d'></div>
# <div id='96825a0a-4405-4f90-b863-35ea2e46b9cb'></div>
# <div id='cd53fc20-0212-4baf-8a74-833a9f7ef728'></div>
# <div id='38141149-481c-4570-86d7-6768f58d0256'></div>
# <div id='15b62fdb-521b-44fb-aaf9-99b494992d08'></div>
# <div id='6ccf3005-ddbf-4478-a255-ff8c4c44f85c'></div>
# <div id='6b65c011-aac9-4e89-a0c3-e5364d64367d'></div>
# <div id='1fdc543e-0b67-4dbf-aa32-a709c65bbe39'></div>
# <div id='ebcd04a8-57c0-47ac-b7aa-fd4b838b869c'></div>
# <div id='e7d5210b-e5b0-4e15-8149-ed98b9d017f3'></div>
# <div id='155f10e7-290a-48a7-9a0e-733ffd13954d'></div>
# <div id='c3ecbb0d-e7e0-4f1f-8b89-6f5284f7e880'></div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-209-d7eba79bcd0b> in <module>()
#       1 g= sns.FacetGrid(train, col="SimpleCategory",col_wrap=2)
#       2 # %time sns.kdeplot(misc.X,misc.Y,shade=True, shade_lowest=False,gridsize=30, clip=clipsize)
# ----> 3 get_ipython().magic('time ax = g.map(sns.jointplot, "X", "Y", bins=20, kind="hex")')
#
# /Users/mtimet/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2161         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2162         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2163         return self.run_line_magic(magic_name, magic_arg_s)
#    2164
#    2165     #-------------------------------------------------------------------------
#
# /Users/mtimet/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2082                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2083             with self.builtin_trap:
# -> 2084                 result = fn(*args,**kwargs)
#    2085             return result
#    2086
#
# <decorator-gen-60> in time(self, line, cell, local_ns)
#
# /Users/mtimet/anaconda/lib/python3.5/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /Users/mtimet/anaconda/lib/python3.5/site-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1175         else:
#    1176             st = clock2()
# -> 1177             exec(code, glob, local_ns)
#    1178             end = clock2()
#    1179             out = None
#
# <timed exec> in <module>()
#
# /Users/mtimet/anaconda/lib/python3.5/site-packages/seaborn/axisgrid.py in map(self, func, *args, **kwargs)
#     696
#     697             # If this subset is null, move on
# --> 698             if not data_ijk.values.size:
#     699                 continue
#     700
#
# /Users/mtimet/anaconda/lib/python3.5/site-packages/pandas/core/generic.py in values(self)
#    2850         int32.
#    2851         """
# -> 2852         return self.as_matrix()
#    2853
#    2854     @property
#
# /Users/mtimet/anaconda/lib/python3.5/site-packages/pandas/core/generic.py in as_matrix(self, columns)
#    2832         self._consolidate_inplace()
#    2833         if self._AXIS_REVERSED:
# -> 2834             return self._data.as_matrix(columns).T
#    2835         return self._data.as_matrix(columns)
#    2836
#
# /Users/mtimet/anaconda/lib/python3.5/site-packages/pandas/core/internals.py in as_matrix(self, items)
#    3148             return mgr.blocks[0].get_values()
#    3149         else:
# -> 3150             return mgr._interleave()
#    3151
#    3152     def _interleave(self):
#
# /Users/mtimet/anaconda/lib/python3.5/site-packages/pandas/core/internals.py in _interleave(self)
#    3175         for blk in self.blocks:
#    3176             rl = blk.mgr_locs
# -> 3177             result[rl.indexer] = blk.get_values(dtype)
#    3178             itemmask[rl.indexer] = 1
#    3179
#
# /Users/mtimet/anaconda/lib/python3.5/site-packages/pandas/core/internals.py in get_values(self, dtype)
#    1516         if com.is_object_dtype(dtype):
#    1517             return lib.map_infer(self.values.ravel(),
# -> 1518                                  self._box_func).reshape(self.values.shape)
#    1519         return self.values
#    1520
#
# KeyboardInterrupt:
